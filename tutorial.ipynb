# %%
# uv pip install cleon

# %%
# !./install.sh --quiet
# Out:
# Staging cleon binary (target=host)...
#     Finished ]8;;https://doc.rust-lang.org/cargo/reference/profiles.html#default-profiles\`release` profile [optimized]]8;;\ target(s) in 0.13s
# Staged cleon to /Users/madhavajay/dev/cleon/workspace1/python/src/cleon/bin
# 🍹 Building a mixed python/rust project
# 🔗 Found pyo3 bindings with abi3 support
# 🐍 Found CPython 3.13 at /Users/madhavajay/dev/cleon/workspace1/.venv/bin/python
# 📡 Using build options features from pyproject.toml
# 💻 Using `MACOSX_DEPLOYMENT_TARGET=11.0` for aarch64-apple-darwin by default
# 📦 Including files matching "src/cleon/py.typed"
# 📦 Including files matching "src/cleon/_cleon.pyi"
# 📦 Including files matching "src/cleon/bin/*"
# 📦 Built wheel for abi3 Python ≥ 3.9 to /Users/madhavajay/dev/cleon/workspace1/dist/cleon-0.1.0-cp39-abi3-macosx_11_0_arm64.whl

# %%
import cleon

# %%
# cleon.auth("codex")

# %%
cleon.use("codex")
# Out:
# Codex session started.
# Add a `>` before your prompt:
#
# > &gt; Whats your name?
# I am Codex!

# %%
> Whats your name?
# Out:
# I go by Codex—happy to help!

# %%
> my favourite fruit is banana
# Out:
# Nice choice—bananas are great!

# %%
cleon.stop()
# Out:
# Session stopped.
# You can resume with:
#   cleon.use("codex", session_id="019a98fe-6f2e-7603-a618-feee16fae6b3")
# or
#   cleon.resume()
# '019a98fe-6f2e-7603-a618-feee16fae6b3'

# %%
> what is my favourite fruit?
# Out:
# '❌ Codex error: cleon session not active. To resume call cleon.resume() or cleon.use(..., session_id=...) or start a new session.'

# %%
cleon.resume()
# Out:
# Codex session started.
# Add a `>` before your prompt:
#
# > &gt; Whats your name?
# I am Codex!
# '019a98fe-6f2e-7603-a618-feee16fae6b3'

# %%
> what is my favourite fruit?
# Out:
# You said your favorite fruit is banana.

# %%
print("hello batman")
# Out:
# hello batman

# %%
> who did i say hi to?
# Out:
# You said hi to Batman.
