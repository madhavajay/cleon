# %%
# !./install.sh --quiet
# Out:
# Staging cleon binary (target=host)...
#     Finished ]8;;https://doc.rust-lang.org/cargo/reference/profiles.html#default-profiles\`release` profile [optimized]]8;;\ target(s) in 0.15s
# Staged cleon to /Users/madhavajay/dev/cleon/workspace2/python/src/cleon/bin
# 🍹 Building a mixed python/rust project
# 🔗 Found pyo3 bindings with abi3 support
# 🐍 Found CPython 3.13 at /Users/madhavajay/dev/cleon/workspace2/.venv/bin/python
# 📡 Using build options features from pyproject.toml
# 💻 Using `MACOSX_DEPLOYMENT_TARGET=11.0` for aarch64-apple-darwin by default
# 📦 Including files matching "src/cleon/py.typed"
# 📦 Including files matching "src/cleon/_cleon.pyi"
# 📦 Including files matching "src/cleon/bin/*"
# 📦 Including files matching "src/cleon/images/*"
# 📦 Built wheel for abi3 Python ≥ 3.9 to /Users/madhavajay/dev/cleon/workspace2/dist/cleon-0.1.11-cp39-abi3-macosx_11_0_arm64.whl

# %%
# !./extension/install.sh

# %%
# !uv pip install -e /Users/madhavajay/dev/cleon/workspace2/extension

# %%
import cleon
# Out:
# <style>
# .cleon-icon {
#     position:absolute;
#     top:8px;
#     right:10px;
#     width:18px;
#     height:18px;
#     opacity:0.7;
#     background-size:contain;
#     background-repeat:no-repeat;
#     pointer-events:none;
# }
# </style>
# Codex session started.
# **Pick an agent with a prefix:**
#
# ```
# @ Whats your name?
# I am Codex!
#
# ~ Whats your name?
# I'm Claude, Anthropic's AI assistant!
#
# > Whats your name?
# I'm Gemini, Google's AI assistant! (use `%%gemini`)
# ```
# Claude session started.

# %%
cleon.has_extension()
# Out:
# True

# %%
cleon.install_extension()
# Out:
# ⚠️  Dev mode detected (CLEON_DEV_MODE is set)
#    Extension should be installed via: ./jupyter.sh

# %%
@ give me code for how to create a python function that adds
two numbers
and then call @ yourself to give me feedback
# Out:
# <div class="cleon-result cleon-bubble-codex" style="position:relative;margin-left:10px;padding:12px 32px 12px 16px;border-radius:12px;border:1px solid #3A3A3A;background:#1F1F1F;color:#F5F5F5;box-shadow:0 8px 18px rgba(0,0,0,0.18);">
# <span class='cleon-icon cleon-icon-codex'></span>
# <div style='background:transparent;color:inherit;font-size:0.95em;line-height:1.5;'><div style='position:relative; margin:8px 0 10px 0;'><button onclick="if (window.cleonInsertAndRun) {  var code = `def add_numbers(a, b):
#     &quot;&quot;&quot;Return the sum of two numbers.&quot;&quot;&quot;
#     return a + b
#
# # quick check
# result = add_numbers(2, 3)
# print(&quot;2 + 3 =&quot;, result)
#
# ...

# %%
def add_numbers(a, b):
    """Return the sum of two numbers."""
    return a + b

# quick check
result = add_numbers(2, 3)
print("2 + 3 =", result)
# Out:
# 2 + 3 = 5

# %%
@ does this look good? Any edge cases you'd like me to cover?
# Out:
# <div class="cleon-result cleon-bubble-codex" style="position:relative;margin-left:10px;padding:12px 32px 12px 16px;border-radius:12px;border:1px solid #3A3A3A;background:#1F1F1F;color:#F5F5F5;box-shadow:0 8px 18px rgba(0,0,0,0.18);">
# <span class='cleon-icon cleon-icon-codex'></span>
# ...

# %%
@ hey chatgpt: I ran the function above and got `result` as output.
# does this look correct? any improvements?

# %%
def add_numbers(a: float, b: float) -> float:
    """Return the sum of a and b."""
    return a + b

result = add_numbers(2, 3)
result  # 5

# %%
@ hey chatgpt how to create a python function that adds two numbers

# %%
@ hey chatgpt, how do I create a Python function that adds two numbers?

# %%
from numbers import Number

def add_numbers(a: Number, b: Number) -> Number:
    return a + b

# %%
from numbers import Number

def add_numbers(a: Number, b: Number) -> Number:
    return a + b

# %%
@ can i ask multi line questions
can i?

# %%
print("test")

@ what do you think?

# %%
import cleon

# %%
~ who are you?

# %%
@ who are you?

# %%
cleon.auth("claude")

# %%
~ test

# %%
~ what model are you running?

# %%
~ what model are you now?

# %%
~ give me a simple mnist class in pytorch

# %%
@ give me a simple mnist class in pytorch

# %%
> who are you?

# %%
> give me a simple mnist class in pytorch

# %%
# cleon.magic.refresh_auto_route()

# %%
print("dfsafdas")

# %%
> who are you?

# %%
print("dfsafdas")

# %%
> what year is it?

# %%
> how big is a banana?

# %%
> what fruit did I just ask you about?

# %%
> whats youar name?

# %%
> what year is it?

# %%
> can you make a file called gemini.txt with the word gemini inside it?

# %%
@ what year is it? and who trained you?

# %%
~ wazzup?

# %%
print("dfsafdas")

# %%
cleon.settings()

# %%
~ can you make a file called a.txt with helloworld in it?

# %%
cleon.use(agent="gemini", name="g", debug=True)

# %%
# cleon.use(agent="gemini", name="g")

# %%
< who are you?

# %%
< what year is it?

# %%
~ Whats your name?

# %%
> Whats your name?

# %%
# cleon.settings(plain_text_output=True)

# %%
# my favourite fruit is banana

# %%
> what is my favourite fruit?

# %%
~ can you make a file called a.txt with the words hello in it?

# %%
cleon.mode()

# %%
cleon.mode("do")

# %%
# i love dogs

# %%
> what animal do i love?

# %%
~ what animal do i love?

# %%
cleon.stop()

# %%
cleon.resume()

# %%
print("hello batman")

# %%
cleon.sessions()

# %%
cleon.reset()
