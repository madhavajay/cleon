# %%
# uv pip install cleon

# %%
# !./install.sh --quiet

# %%
import cleon

# %%
> Whats your name?

# %%
> my favourite fruit is banana

# %%
cleon.stop()

# %%
> what is my favourite fruit?

# %%
cleon.resume()

# %%
> what is my favourite fruit?

# %%
print("hello batman")

# %%
> who did i say hi to?

# %%
cleon.stop()

# %%
cleon.sessions()

# %%
cleon.reset()
