# %%
# uv pip install cleon

# %%
# !./install.sh --quiet
# Out:
# Staging cleon binary (target=host)...
#     Finished ]8;;https://doc.rust-lang.org/cargo/reference/profiles.html#default-profiles\`release` profile [optimized]]8;;\ target(s) in 0.15s
# Staged cleon to /Users/madhavajay/dev/cleon/workspace2/python/src/cleon/bin
# 🍹 Building a mixed python/rust project
# 🔗 Found pyo3 bindings with abi3 support
# 🐍 Found CPython 3.13 at /Users/madhavajay/dev/cleon/workspace2/.venv/bin/python
# 📡 Using build options features from pyproject.toml
# 💻 Using `MACOSX_DEPLOYMENT_TARGET=11.0` for aarch64-apple-darwin by default
# 📦 Including files matching "src/cleon/py.typed"
# 📦 Including files matching "src/cleon/_cleon.pyi"
# 📦 Including files matching "src/cleon/bin/*"
# 📦 Including files matching "src/cleon/images/*"
# 📦 Built wheel for abi3 Python ≥ 3.9 to /Users/madhavajay/dev/cleon/workspace2/dist/cleon-0.1.9-cp39-abi3-macosx_11_0_arm64.whl

# %%
# cleon.reset()

# %%
import cleon
# Out:
# <style>
# .cleon-icon {
#     position:absolute;
#     top:8px;
#     right:10px;
#     width:18px;
#     height:18px;
#     opacity:0.7;
#     background-size:contain;
#     background-repeat:no-repeat;
#     pointer-events:none;
# }
# </style>
# Codex session started.
# Add a `>` or `~` before your prompt to invoke Codex or Claude:
#
# > &gt; Whats your name?
# I am Codex!
#
# ~ Whats your name?
# I'm Claude, Anthropic's AI assistant!
# Backend 'claude' does not support async mode; falling back to synchronous turns.
# Claude session started.

# %%
~ Whats your name?
# Out:
# <div class="cleon-result cleon-bubble-claude" style="position:relative;margin-left:10px;padding:12px 32px 12px 16px;border-radius:12px;border:1px solid #4A4A45;background:#262624;color:#F7F5F2;box-shadow:0 8px 18px rgba(0,0,0,0.18);">
# <span class='cleon-icon cleon-icon-claude'></span>
# <div style='background:transparent;color:inherit;font-size:0.95em;line-height:1.5;'><pre style='margin:0;white-space:pre-wrap;font-size:0.95em;background:transparent;color:inherit;'>I&#x27;m Claude, Anthropic&#x27;s AI assistant!
#
# In this context, you&#x27;re interacting with me through the `%%claude` cell magic in your Jupyter notebook, which allows you to send prompts directly to me and get responses.
#
# Is there anything you&#x27;d like help with today?</pre></div>
# </div>
# <style>
# @media (prefers-color-scheme: dark) {
#     .cleon-bubble-claude {
#         background: #262624;
#         border-color: #4A4A45;
#         color: #F7F5F2;
#     }
# }
# </style>
# <style>.cleon-icon-claude { background-image:url('data:image/png;base64,...'); }</style>

# %%
> Whats your name?
# Out:
# <div class="cleon-result cleon-bubble-codex" style="position:relative;margin-left:10px;padding:12px 32px 12px 16px;border-radius:12px;border:1px solid #3A3A3A;background:#1F1F1F;color:#F5F5F5;box-shadow:0 8px 18px rgba(0,0,0,0.18);">
# <span class='cleon-icon cleon-icon-codex'></span>
# <div style='background:transparent;color:inherit;font-size:0.95em;line-height:1.5;'><pre style='margin:0;white-space:pre-wrap;font-size:0.95em;background:transparent;color:inherit;'>I&#x27;m Claude, an AI assistant here to help in your notebook.</pre></div>
# </div>
# <style>
# @media (prefers-color-scheme: dark) {
#     .cleon-bubble-codex {
#         background: #1F1F1F;
#         border-color: #3A3A3A;
#         color: #F5F5F5;
#     }
# }
# </style>

# %%
# my favourite fruit is banana

# %%
> what is my favourite fruit?
# Out:
# <div class="cleon-result cleon-bubble-codex" style="position:relative;margin-left:10px;padding:12px 32px 12px 16px;border-radius:12px;border:1px solid #3A3A3A;background:#1F1F1F;color:#F5F5F5;box-shadow:0 8px 18px rgba(0,0,0,0.18);">
# <span class='cleon-icon cleon-icon-codex'></span>
# <div style='background:transparent;color:inherit;font-size:0.95em;line-height:1.5;'><pre style='margin:0;white-space:pre-wrap;font-size:0.95em;background:transparent;color:inherit;'>From your note in cell 11, your favorite fruit is banana. 🍌</pre></div>
# </div>
# <style>
# @media (prefers-color-scheme: dark) {
#     .cleon-bubble-codex {
#         background: #1F1F1F;
#         border-color: #3A3A3A;
#         color: #F5F5F5;
#     }
# }
# </style>

# %%
~ what is my favourite fruit?
# Out:
# <div class="cleon-result cleon-bubble-claude" style="position:relative;margin-left:10px;padding:12px 32px 12px 16px;border-radius:12px;border:1px solid #4A4A45;background:#262624;color:#F7F5F2;box-shadow:0 8px 18px rgba(0,0,0,0.18);">
# <span class='cleon-icon cleon-icon-claude'></span>
# <div style='background:transparent;color:inherit;font-size:0.95em;line-height:1.5;'><pre style='margin:0;white-space:pre-wrap;font-size:0.95em;background:transparent;color:inherit;'>Based on the context provided, I can see from cell 11 that you wrote:
#
# ```python
# # my favourite fruit is banana
# ```
#
# So your favourite fruit is **banana**! 🍌</pre></div>
# </div>
# <style>
# @media (prefers-color-scheme: dark) {
#     .cleon-bubble-claude {
#         background: #262624;
#         border-color: #4A4A45;
#         color: #F7F5F2;
#     }
# }
# </style>
# <style>.cleon-icon-claude { background-image:url('data:image/png;base64,...'); }</style>

# %%
# i love dogs

# %%
> what animal do i love?
# Out:
# <div class="cleon-result cleon-bubble-codex" style="position:relative;margin-left:10px;padding:12px 32px 12px 16px;border-radius:12px;border:1px solid #3A3A3A;background:#1F1F1F;color:#F5F5F5;box-shadow:0 8px 18px rgba(0,0,0,0.18);">
# <span class='cleon-icon cleon-icon-codex'></span>
# <div style='background:transparent;color:inherit;font-size:0.95em;line-height:1.5;'><pre style='margin:0;white-space:pre-wrap;font-size:0.95em;background:transparent;color:inherit;'>You mentioned in cell 14 that you love dogs. 🐕</pre></div>
# </div>
# <style>
# @media (prefers-color-scheme: dark) {
#     .cleon-bubble-codex {
#         background: #1F1F1F;
#         border-color: #3A3A3A;
#         color: #F5F5F5;
#     }
# }
# </style>

# %%
~ what animal do i love?
# Out:
# <div class="cleon-result cleon-bubble-claude" style="position:relative;margin-left:10px;padding:12px 32px 12px 16px;border-radius:12px;border:1px solid #4A4A45;background:#262624;color:#F7F5F2;box-shadow:0 8px 18px rgba(0,0,0,0.18);">
# <span class='cleon-icon cleon-icon-claude'></span>
# <div style='background:transparent;color:inherit;font-size:0.95em;line-height:1.5;'><pre style='margin:0;white-space:pre-wrap;font-size:0.95em;background:transparent;color:inherit;'>Based on the context provided, I can see from cell 14 that you wrote:
#
# ```python
# # i love dogs
# ```
#
# So the animal you love is **dogs**! 🐕</pre></div>
# </div>
# <style>
# @media (prefers-color-scheme: dark) {
#     .cleon-bubble-claude {
#         background: #262624;
#         border-color: #4A4A45;
#         color: #F7F5F2;
#     }
# }
# </style>
# <style>.cleon-icon-codex { background-image:url('data:image/png;base64,...'); }</style>
# <style>.cleon-icon-claude { background-image:url('data:image/png;base64,...'); }</style>
# <style>.cleon-icon-codex { background-image:url('data:image/png;base64,...'); }</style>
# <style>.cleon-icon-codex { background-image:url('data:image/png;base64,...'); }</style>

# %%
cleon.stop("codex")

# %%
> ?

# %%
cleon.stop("claude")

# %%
~ ?

# %%
cleon.resume()

# %%
> what is my favourite fruit?

# %%
print("hello batman")

# %%
cleon.use("claude")

# %%
~ who did i say hi to?

# %%
cleon.sessions()

# %%
cleon.reset()
